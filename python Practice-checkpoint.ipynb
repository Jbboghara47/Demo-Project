# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
data=sns.load_dataset('flights')

# %%
data
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
data.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
data.month.unique()
# Out:
# ['Jan', 'Feb', 'Mar', 'Apr', 'May', ..., 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
# Length: 12
# Categories (12, object): ['Jan', 'Feb', 'Mar', 'Apr', ..., 'Sep', 'Oct', 'Nov', 'Dec']

# %%
data.month.value_counts()
# Out:
# month
# Jan    12
# Feb    12
# Mar    12
# Apr    12
# May    12
# Jun    12
# Jul    12
# Aug    12
# Sep    12
# Oct    12
# Nov    12
# Dec    12
# Name: count, dtype: int64

# %%
sns.lineplot(x ='year',y= 'passengers',data=data,ci=None)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_7772\1572835214.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x ='year',y= 'passengers',data=data,ci=None)
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.lineplot(x ='year',y= 'passengers',data=data,hue = month,ci=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 sns.lineplot(x ='year',y= 'passengers',data=data,hue = month,ci=None)
#
# NameError: name 'month' is not defined

# %%
sns.barplot(x ='month',y ='passengers', data=data)
# Out:
# <Axes: xlabel='month', ylabel='passengers'>

# %%
data.passengers.loc[(data['month']=='Jan')].mean()
# Out:
# 241.75

# %%
sns.boxplot(x = 'month' , data=data)
# Out:
# <Axes: xlabel='month'>

# %%
sns.boxplot(x = 'passengers' , data=data)
# Out:
# <Axes: xlabel='passengers'>

# %%
sns.boxplot(x = 'month', y = 'passengers', data=data)
# Out:
# <Axes: xlabel='month', ylabel='passengers'>

# %%
sns.histplot(x = 'passengers', kde=1 ,data=data)
# Out:
# <Axes: xlabel='passengers', ylabel='Count'>

# %%
sns.catplot(x='passengers', data=data, kind='violin') # kind = which ploat print
plt.show()

# %%
sns.countplot(data=data)
# Out:
# <Axes: ylabel='count'>

# %%
data
# Out:
#      year  passengers
# 0    1949         112
# 1    1949         118
# 2    1949         132
# 3    1949         129
# 4    1949         121
# ..    ...         ...
# 139  1960         606
# 140  1960         508
# 141  1960         461
# 142  1960         390
# 143  1960         432
#
# [144 rows x 2 columns]

# %%
sns.heatmap(data,annot=True)
# Out:
# <Axes: >

# %%
corr = data.corr(numeric_only=True)
plt.figure(figsize=(10,10))
sns.heatmap(corr,annot=True,cmap='YlGnBu')  # Annot=True is show the number
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
